# %%
import models
import torch
import chess
import chess_engine

m = models.create('ChessEngine.v0')
m.load_state_dict(torch.load('saved_models/2018-01-08/ChessEngine_2018-01-09_22:26:13_11.model'))
e = chess_engine.ChessEngine(m)
b = chess.Board()

# %%
b
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %%
chess_engine.push_move(b, 'c2c4')
# Out:
# Board('rnbqkbnr/pppppppp/8/8/2P5/8/PP1PPPPP/RNBQKBNR b KQkq - 0 1')

# %%
e.make_move(b)
# Out:
# Board('rnbqkbnr/ppppp1pp/8/5p2/2P5/8/PP1PPPPP/RNBQKBNR w KQkq - 0 2')

# %%
chess_engine.push_move(b, 'd2d4')
# Out:
# Board('rnbqkbnr/ppppp1pp/8/5p2/2PP4/8/PP2PPPP/RNBQKBNR b KQkq - 0 2')

# %%
e.make_move(b)
# Out:
# Board('rnbqkb1r/ppppp1pp/5n2/5p2/2PP4/8/PP2PPPP/RNBQKBNR w KQkq - 1 3')

# %%
from chess_engine import push_move

# %%
push_move(b, 'b1c3')
# Out:
# Board('rnbqkb1r/ppppp1pp/5n2/5p2/2PP4/2N5/PP2PPPP/R1BQKBNR b KQkq - 2 3')

# %%
e.make_move(b)
# Out:
# Board('rnbqkb1r/ppppp1pp/5n2/8/2PP1p2/2N5/PP2PPPP/R1BQKBNR w KQkq - 0 4')

# %%
push_move(b, 'c1f4')
# Out:
# Board('rnbqkb1r/ppppp1pp/5n2/8/2PP1B2/2N5/PP2PPPP/R2QKBNR b KQkq - 0 4')

# %%
e.make_move(b)
# Out:
# Board('r1bqkb1r/ppppp1pp/2n2n2/8/2PP1B2/2N5/PP2PPPP/R2QKBNR w KQkq - 1 5')

# %%
def make_move():
    return e.make_move(b)

# %%
push_move(b, 'g1f3')
# Out:
# Board('r1bqkb1r/ppppp1pp/2n2n2/8/2PP1B2/2N2N2/PP2PPPP/R2QKB1R b KQkq - 2 5')

# %%
make_move()

# %%
b
# Out:
# Board('r1bqkb1r/ppppp1pp/2n5/8/2PP1Bn1/2N2N2/PP2PPPP/R2QKB1R w KQkq - 3 6')

# %%
def push(uci):
    return push_move(b, uci)

# %%
push('e2e3')
# Out:
# Board('r1bqkb1r/ppppp1pp/2n5/8/2PP1Bn1/2N1PN2/PP3PPP/R2QKB1R b KQkq - 0 6')

# %%
make_move()
# Out:
# Board('r1bqkb1r/ppp1p1pp/2np4/8/2PP1Bn1/2N1PN2/PP3PPP/R2QKB1R w KQkq - 0 7')

# %%
push('f1e2')
# Out:
# Board('r1bqkb1r/ppp1p1pp/2np4/8/2PP1Bn1/2N1PN2/PP2BPPP/R2QK2R b KQkq - 1 7')

# %%
make_move()
# Out:
# Board('r2qkb1r/ppp1p1pp/2npb3/8/2PP1Bn1/2N1PN2/PP2BPPP/R2QK2R w KQkq - 2 8')

# %%
push('d4d5')
# Out:
# Board('r2qkb1r/ppp1p1pp/2npb3/3P4/2P2Bn1/2N1PN2/PP2BPPP/R2QK2R b KQkq - 0 8')

# %%
make_move()
# Out:
# Board('r2qkbbr/ppp1p1pp/2np4/3P4/2P2Bn1/2N1PN2/PP2BPPP/R2QK2R w KQkq - 1 9')

# %%
push('d5c6')
# Out:
# Board('r2qkbbr/ppp1p1pp/2Pp4/8/2P2Bn1/2N1PN2/PP2BPPP/R2QK2R b KQkq - 0 9')

# %%
make_move()
# Out:
# Board('r2qkbbr/ppp1p1pp/2Pp1n2/8/2P2B2/2N1PN2/PP2BPPP/R2QK2R w KQkq - 1 10')

# %%
push('c6b7')
# Out:
# Board('r2qkbbr/pPp1p1pp/3p1n2/8/2P2B2/2N1PN2/PP2BPPP/R2QK2R b KQkq - 0 10')

# %%
make_move()
# Out:
# Board('r2qkbbr/pPpnp1pp/3p4/8/2P2B2/2N1PN2/PP2BPPP/R2QK2R w KQkq - 1 11')

# %%
push('b7a8q')
# Out:
# Board('Q2qkbbr/p1pnp1pp/3p4/8/2P2B2/2N1PN2/PP2BPPP/R2QK2R b KQk - 0 11')

# %%
make_move()
# Out:
# Board('q3kbbr/p1pnp1pp/3p4/8/2P2B2/2N1PN2/PP2BPPP/R2QK2R w KQk - 0 12')

# %%
push('c3d5')
# Out:
# Board('q3kbbr/p1pnp1pp/3p4/3N4/2P2B2/4PN2/PP2BPPP/R2QK2R b KQk - 1 12')

# %%
make_move()
# Out:
# Board('q3kb1r/p1pnp1pp/3p4/3b4/2P2B2/4PN2/PP2BPPP/R2QK2R w KQk - 0 13')

# %%
push('d1d5')
# Out:
# Board('q3kb1r/p1pnp1pp/3p4/3Q4/2P2B2/4PN2/PP2BPPP/R3K2R b KQk - 0 13')

# %%
make_move()
# Out:
# Board('q3kb1r/p2np1pp/3p4/2pQ4/2P2B2/4PN2/PP2BPPP/R3K2R w KQk - 0 14')

# %%
push('d5a8')
# Out:
# Board('Q3kb1r/p2np1pp/3p4/2p5/2P2B2/4PN2/PP2BPPP/R3K2R b KQk - 0 14')

# %%
make_move()
# Out:
# Board('Q4b1r/p2npkpp/3p4/2p5/2P2B2/4PN2/PP2BPPP/R3K2R w KQ - 1 15')

# %%
push('f3g5')
# Out:
# Board('Q4b1r/p2npkpp/3p4/2p3N1/2P2B2/4P3/PP2BPPP/R3K2R b KQ - 2 15')

# %%
make_move()
# Out:
# Board('Q4b1r/p2np1pp/3p1k2/2p3N1/2P2B2/4P3/PP2BPPP/R3K2R w KQ - 3 16')

# %%
push('a8d5')
# Out:
# Board('5b1r/p2np1pp/3p1k2/2pQ2N1/2P2B2/4P3/PP2BPPP/R3K2R b KQ - 4 16')

# %%
make_move()
# Out:
# Board('1n3b1r/p3p1pp/3p1k2/2pQ2N1/2P2B2/4P3/PP2BPPP/R3K2R w KQ - 5 17')

# %%
push('d5e6')
# Out:
# Board('1n3b1r/p3p1pp/3pQk2/2p3N1/2P2B2/4P3/PP2BPPP/R3K2R b KQ - 6 17')
