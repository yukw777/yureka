# %%
import models
import torch
import chess
import chess_engine

m = models.create('ChessEngine.v0')
m.load_state_dict(torch.load('saved_models/2018-01-08/ChessEngine_2018-01-09_22:26:13_11.model'))
e = chess_engine.ChessEngine(m, train=False)
b = chess.Board() 

def push(uci):
    b.push_move(chess.Move.from_uci(uci))
    return b

def make_move():
    return e.make_move(b)

# %%
make_move()
# Out:
# Board('rnbqkbnr/pppppppp/8/8/3P4/8/PPP1PPPP/RNBQKBNR b KQkq - 0 1')

# %%
push('d7d5')
# Out:
# Board('rnbqkbnr/ppp1pppp/8/3p4/3P4/8/PPP1PPPP/RNBQKBNR w KQkq - 0 2')

# %%
make_move()
# Out:
# Board('rnbqkbnr/ppp1pppp/8/3p4/2PP4/8/PP2PPPP/RNBQKBNR b KQkq - 0 2')

# %%
push('e7e6')
# Out:
# Board('rnbqkbnr/ppp2ppp/4p3/3p4/2PP4/8/PP2PPPP/RNBQKBNR w KQkq - 0 3')

# %%
make_move()
# Out:
# Board('rnbqkbnr/ppp2ppp/4p3/3p4/2PP4/2N5/PP2PPPP/R1BQKBNR b KQkq - 1 3')

# %%
push('g8f6')
# Out:
# Board('rnbqkb1r/ppp2ppp/4pn2/3p4/2PP4/2N5/PP2PPPP/R1BQKBNR w KQkq - 2 4')

# %%
make_move()
# Out:
# Board('rnbqkb1r/ppp2ppp/4pn2/3P4/3P4/2N5/PP2PPPP/R1BQKBNR b KQkq - 0 4')

# %%
push('e6d5')
# Out:
# Board('rnbqkb1r/ppp2ppp/5n2/3p4/3P4/2N5/PP2PPPP/R1BQKBNR w KQkq - 0 5')

# %%
make_move()
# Out:
# Board('rnbqkb1r/ppp2ppp/5n2/3p2B1/3P4/2N5/PP2PPPP/R2QKBNR b KQkq - 1 5')

# %%
push('f8e7')
# Out:
# Board('rnbqk2r/ppp1bppp/5n2/3p2B1/3P4/2N5/PP2PPPP/R2QKBNR w KQkq - 2 6')

# %%
make_move()
# Out:
# Board('rnbqk2r/ppp1bppp/5n2/3p2B1/3P4/2N1P3/PP3PPP/R2QKBNR b KQkq - 0 6')

# %%
push('e8g8')
# Out:
# Board('rnbq1rk1/ppp1bppp/5n2/3p2B1/3P4/2N1P3/PP3PPP/R2QKBNR w KQ - 1 7')

# %%
make_move()
# Out:
# Board('rnbq1rk1/ppp1bppp/5n2/3p2B1/3P4/2NBP3/PP3PPP/R2QK1NR b KQ - 2 7')

# %%
push('c8g4')
# Out:
# Board('rn1q1rk1/ppp1bppp/5n2/3p2B1/3P2b1/2NBP3/PP3PPP/R2QK1NR w KQ - 3 8')

# %%
make_move()
# Out:
# Board('rn1q1rk1/ppp1bppp/5n2/3p2B1/3P2b1/2NBP3/PP2NPPP/R2QK2R b KQ - 4 8')

# %%
push('b8d7')
# Out:
# Board('r2q1rk1/pppnbppp/5n2/3p2B1/3P2b1/2NBP3/PP2NPPP/R2QK2R w KQ - 5 9')

# %%
make_move()
# Out:
# Board('r2q1rk1/pppnbppp/5n2/3p2B1/3P2b1/2NBP3/PP2NPPP/R2Q1RK1 b - - 6 9')

# %%
push('c7c5')
# Out:
# Board('r2q1rk1/pp1nbppp/5n2/2pp2B1/3P2b1/2NBP3/PP2NPPP/R2Q1RK1 w - - 0 10')

# %%
make_move()
# Out:
# Board('r2q1rk1/pp1nbppp/5n2/2pp2B1/3P2b1/2NBPP2/PP2N1PP/R2Q1RK1 b - - 0 10')

# %%
push('g4e6')
# Out:
# Board('r2q1rk1/pp1nbppp/4bn2/2pp2B1/3P4/2NBPP2/PP2N1PP/R2Q1RK1 w - - 1 11')

# %%
make_move()
# Out:
# Board('r2q1rk1/pp1nbppp/4bn2/2pp2B1/3P1N2/2NBPP2/PP4PP/R2Q1RK1 b - - 2 11')

# %%
push('h7h6')
# Out:
# Board('r2q1rk1/pp1nbpp1/4bn1p/2pp2B1/3P1N2/2NBPP2/PP4PP/R2Q1RK1 w - - 0 12')

# %%
make_move()
# Out:
# Board('r2q1rk1/pp1nbpp1/4bn1p/2pp4/3P1N1B/2NBPP2/PP4PP/R2Q1RK1 b - - 1 12')

# %%
push('g7g5')
# Out:
# Board('r2q1rk1/pp1nbp2/4bn1p/2pp2p1/3P1N1B/2NBPP2/PP4PP/R2Q1RK1 w - - 0 13')

# %%
make_move()
# Out:
# Board('r2q1rk1/pp1nbp2/4bn1p/2pp2p1/3P1N2/2NBPPB1/PP4PP/R2Q1RK1 b - - 1 13')

# %%
push('g5f4')
# Out:
# Board('r2q1rk1/pp1nbp2/4bn1p/2pp4/3P1p2/2NBPPB1/PP4PP/R2Q1RK1 w - - 0 14')

# %%
make_move()
# Out:
# Board('r2q1rk1/pp1nbp2/4bn1p/2pp4/3P1B2/2NBPP2/PP4PP/R2Q1RK1 b - - 0 14')

# %%
push('b7b6')
# Out:
# Board('r2q1rk1/p2nbp2/1p2bn1p/2pp4/3P1B2/2NBPP2/PP4PP/R2Q1RK1 w - - 0 15')

# %%
make_move()
# Out:
# Board('r2q1rk1/p2nbp2/1p2bn1B/2pp4/3P4/2NBPP2/PP4PP/R2Q1RK1 b - - 0 15')

# %%
push('f6h5')
# Out:
# Board('r2q1rk1/p2nbp2/1p2b2B/2pp3n/3P4/2NBPP2/PP4PP/R2Q1RK1 w - - 1 16')

# %%
make_move()
# Out:
# Board('r2q1Bk1/p2nbp2/1p2b3/2pp3n/3P4/2NBPP2/PP4PP/R2Q1RK1 b - - 0 16')

# %%
push('g8f8')
# Out:
# Board('r2q1k2/p2nbp2/1p2b3/2pp3n/3P4/2NBPP2/PP4PP/R2Q1RK1 w - - 0 17')

# %%
make_move()
# Out:
# Board('r2q1k2/p2nbp2/1p2b3/2Pp3n/8/2NBPP2/PP4PP/R2Q1RK1 b - - 0 17')

# %%
push('d7c5')
# Out:
# Board('r2q1k2/p3bp2/1p2b3/2np3n/8/2NBPP2/PP4PP/R2Q1RK1 w - - 0 18')

# %%
make_move()
# Out:
# Board('r2q1k2/p3bp2/1p2b3/1Nnp3n/8/3BPP2/PP4PP/R2Q1RK1 b - - 1 18')

# %%
push('a8c8')
# Out:
# Board('2rq1k2/p3bp2/1p2b3/1Nnp3n/8/3BPP2/PP4PP/R2Q1RK1 w - - 2 19')

# %%
make_move()
# Out:
# Board('2rq1k2/p3bp2/1p2b3/2np3n/3N4/3BPP2/PP4PP/R2Q1RK1 b - - 3 19')

# %%
push('d8d6')
# Out:
# Board('2r2k2/p3bp2/1p1qb3/2np3n/3N4/3BPP2/PP4PP/R2Q1RK1 w - - 4 20')

# %%
make_move()
# Out:
# Board('2r2k2/p3bp2/1p1qN3/2np3n/8/3BPP2/PP4PP/R2Q1RK1 b - - 0 20')

# %%
push('c5e6')
# Out:
# Board('2r2k2/p3bp2/1p1qn3/3p3n/8/3BPP2/PP4PP/R2Q1RK1 w - - 0 21')

# %%
make_move()
# Out:
# Board('2r2k2/p3bp2/1p1qn3/3p3n/8/3BPP2/PP4PP/2RQ1RK1 b - - 1 21')

# %%
push('c8c5')
# Out:
# Board('5k2/p3bp2/1p1qn3/2rp3n/8/3BPP2/PP4PP/2RQ1RK1 w - - 2 22')

# %%
make_move()
# Out:
# Board('5k2/p3bp2/1p1qn3/2Rp3n/8/3BPP2/PP4PP/3Q1RK1 b - - 0 22')

# %%
push('e6c5')
# Out:
# Board('5k2/p3bp2/1p1q4/2np3n/8/3BPP2/PP4PP/3Q1RK1 w - - 0 23')

# %%
make_move()
# Out:
# Board('5k2/p3bp2/1p1q4/1Bnp3n/8/4PP2/PP4PP/3Q1RK1 b - - 1 23')

# %%
push('d5d4')
# Out:
# Board('5k2/p3bp2/1p1q4/1Bn4n/3p4/4PP2/PP4PP/3Q1RK1 w - - 0 24')

# %%
make_move()
# Out:
# Board('5k2/p3bp2/1p1q4/1Bn4n/3Q4/4PP2/PP4PP/5RK1 b - - 0 24')

# %%
push('h5g7')
# Out:
# Board('5k2/p3bpn1/1p1q4/1Bn5/3Q4/4PP2/PP4PP/5RK1 w - - 1 25')

# %%
make_move()
# Out:
# Board('5k2/p3bpn1/1p1Q4/1Bn5/8/4PP2/PP4PP/5RK1 b - - 0 25')

# %%
push('e7d6')
# Out:
# Board('5k2/p4pn1/1p1b4/1Bn5/8/4PP2/PP4PP/5RK1 w - - 0 26')

# %%
make_move()
# Out:
# Board('5k2/p4pn1/1p1b4/1Bn5/8/4PP2/PP4PP/3R2K1 b - - 1 26')

# %%
push('d6e7')
# Out:
# Board('5k2/p3bpn1/1p6/1Bn5/8/4PP2/PP4PP/3R2K1 w - - 2 27')

# %%
make_move()
# Out:
# Board('5k2/p3bpn1/1p6/1Bn5/8/4PP2/PP3KPP/3R4 b - - 3 27')

# %%
push('a7a5')
# Out:
# Board('5k2/4bpn1/1p6/pBn5/8/4PP2/PP3KPP/3R4 w - - 0 28')

# %%
make_move()
# Out:
# Board('5k2/4bpn1/1p6/pBnR4/8/4PP2/PP3KPP/8 b - - 1 28')

# %%
push('g7e6')
# Out:
# Board('5k2/4bp2/1p2n3/pBnR4/8/4PP2/PP3KPP/8 w - - 2 29')

# %%
make_move()
# Out:
# Board('5k2/4bp2/1p2n3/pBnR4/8/4PP2/PP2K1PP/8 b - - 3 29')

# %%
push('e6c7')
# Out:
# Board('5k2/2n1bp2/1p6/pBnR4/8/4PP2/PP2K1PP/8 w - - 4 30')

# %%
make_move()
# Out:
# Board('5k2/2n1bp2/1p6/pBn4R/8/4PP2/PP2K1PP/8 b - - 5 30')

# %%
push('c7b5')
# Out:
# Board('5k2/4bp2/1p6/pnn4R/8/4PP2/PP2K1PP/8 w - - 0 31')

# %%
make_move()
# Out:
# Board('5k1R/4bp2/1p6/pnn5/8/4PP2/PP2K1PP/8 b - - 1 31')

# %%
push('f8g7')
# Out:
# Board('7R/4bpk1/1p6/pnn5/8/4PP2/PP2K1PP/8 w - - 2 32')

# %%
make_move()
# Out:
# Board('2R5/4bpk1/1p6/pnn5/8/4PP2/PP2K1PP/8 b - - 3 32')

# %%
push('a5a4')
# Out:
# Board('2R5/4bpk1/1p6/1nn5/p7/4PP2/PP2K1PP/8 w - - 0 33')

# %%
make_move()
# Out:
# Board('8/4bpk1/1pR5/1nn5/p7/4PP2/PP2K1PP/8 b - - 1 33')

# %%
push('a4a3')
# Out:
# Board('8/4bpk1/1pR5/1nn5/8/p3PP2/PP2K1PP/8 w - - 0 34')

# %%
make_move()
# Out:
# Board('8/4bpk1/1pR5/1nn5/1P6/p3PP2/P3K1PP/8 b - - 0 34')

# %%
push('b4c3')
# Out:
# Board('8/4bpk1/1pR5/1nn5/8/p1p1PP2/P3K1PP/8 w - - 0 35')

# %%
b.pop()
b
# Out:
# Board('8/4bpk1/1pR5/1nn5/1P6/p3PP2/P3K1PP/8 b - - 0 34')

# %%
push('b5c3')
# Out:
# Board('8/4bpk1/1pR5/2n5/1P6/p1n1PP2/P3K1PP/8 w - - 1 35')

# %%
make_move()
# Out:
# Board('8/4bpk1/1pR5/2n5/1P6/p1n1PP2/P2K2PP/8 b - - 2 35')

# %%
push('c3b1')
# Out:
# Board('8/4bpk1/1pR5/2n5/1P6/p3PP2/P2K2PP/1n6 w - - 3 36')

# %%
make_move()
# Out:
# Board('8/4bpk1/1pR5/2n5/1P6/p3PP2/P1K3PP/1n6 b - - 4 36')

# %%
push('b1d2')
# Out:
# Board('8/4bpk1/1pR5/2n5/1P6/p3PP2/P1Kn2PP/8 w - - 5 37')

# %%
make_move()
# Out:
# Board('8/4bpk1/1pR5/2P5/8/p3PP2/P1Kn2PP/8 b - - 0 37')

# %%
push('b6c5')
# Out:
# Board('8/4bpk1/2R5/2p5/8/p3PP2/P1Kn2PP/8 w - - 0 38')

# %%
make_move()
# Out:
# Board('8/4bpk1/2R5/2p5/8/p3PP2/P2K2PP/8 b - - 0 38')

# %%
push('e7f6')
# Out:
# Board('8/5pk1/2R2b2/2p5/8/p3PP2/P2K2PP/8 w - - 1 39')

# %%
make_move()
# Out:
# Board('8/5pk1/5b2/2R5/8/p3PP2/P2K2PP/8 b - - 0 39')

# %%
push('f6e7')
# Out:
# Board('8/4bpk1/8/2R5/8/p3PP2/P2K2PP/8 w - - 1 40')

# %%
make_move()
# Out:
# Board('8/2R1bpk1/8/8/8/p3PP2/P2K2PP/8 b - - 2 40')

# %%
push('e7b4')
# Out:
# Board('8/2R2pk1/8/8/1b6/p3PP2/P2K2PP/8 w - - 3 41')

# %%
make_move()
# Out:
# Board('8/2R2pk1/8/8/1b6/p2KPP2/P5PP/8 b - - 4 41')

# %%
push('b4d6')
# Out:
# Board('8/2R2pk1/3b4/8/8/p2KPP2/P5PP/8 w - - 5 42')

# %%
make_move()
# Out:
# Board('8/5pk1/2Rb4/8/8/p2KPP2/P5PP/8 b - - 6 42')

# %%
push('d6h2')
# Out:
# Board('8/5pk1/2R5/8/8/p2KPP2/P5Pb/8 w - - 0 43')

# %%
make_move()
# Out:
# Board('8/5pk1/R7/8/8/p2KPP2/P5Pb/8 b - - 1 43')

# %%
push('h2e5')
# Out:
# Board('8/5pk1/R7/4b3/8/p2KPP2/P5P1/8 w - - 2 44')

# %%
make_move()
# Out:
# Board('8/5pk1/R7/4b3/4K3/p3PP2/P5P1/8 b - - 3 44')

# %%
push('e5f6')
# Out:
# Board('8/5pk1/R4b2/8/4K3/p3PP2/P5P1/8 w - - 4 45')

# %%
make_move()
# Out:
# Board('8/5pk1/R4b2/5K2/8/p3PP2/P5P1/8 b - - 5 45')

# %%
push('f6e7')
# Out:
# Board('8/4bpk1/R7/5K2/8/p3PP2/P5P1/8 w - - 6 46')

# %%
make_move()
# Out:
# Board('8/4bpk1/R7/5K2/4P3/p4P2/P5P1/8 b - - 0 46')

# %%
push('g7f8')
# Out:
# Board('5k2/4bp2/R7/5K2/4P3/p4P2/P5P1/8 w - - 1 47')

# %%
make_move()
# Out:
# Board('5k2/4bp2/R7/4PK2/8/p4P2/P5P1/8 b - - 0 47')

# %%
push('f7f6')
# Out:
# Board('5k2/4b3/R4p2/4PK2/8/p4P2/P5P1/8 w - - 0 48')

# %%
make_move()
# Out:
# Board('5k2/4b3/R4P2/5K2/8/p4P2/P5P1/8 b - - 0 48')

# %%
push('e7d8')
# Out:
# Board('3b1k2/8/R4P2/5K2/8/p4P2/P5P1/8 w - - 1 49')

# %%
make_move()
# Out:
# Board('3b1k2/8/5P2/5K2/8/R4P2/P5P1/8 b - - 0 49')

# %%
push('f8e8')
# Out:
# Board('3bk3/8/5P2/5K2/8/R4P2/P5P1/8 w - - 1 50')

# %%
make_move()
# Out:
# Board('R2bk3/8/5P2/5K2/8/5P2/P5P1/8 b - - 2 50')

# %%
push('e8d7')
# Out:
# Board('R2b4/3k4/5P2/5K2/8/5P2/P5P1/8 w - - 3 51')

# %%
make_move()
# Out:
# Board('R2b4/3k4/5P2/5K2/6P1/5P2/P7/8 b - - 0 51')

# %%
push('d8c7')
# Out:
# Board('R7/2bk4/5P2/5K2/6P1/5P2/P7/8 w - - 1 52')

# %%
make_move()
# Out:
# Board('R7/2bk4/5P2/5KP1/8/5P2/P7/8 b - - 0 52')

# %%
push('d7c6')
# Out:
# Board('R7/2b5/2k2P2/5KP1/8/5P2/P7/8 w - - 1 53')

# %%
make_move()
# Out:
# Board('R7/2b5/2k2PP1/5K2/8/5P2/P7/8 b - - 0 53')

# %%
push('c6b7')
# Out:
# Board('R7/1kb5/5PP1/5K2/8/5P2/P7/8 w - - 1 54')

# %%
make_move()
# Out:
# Board('R7/1kb2P2/6P1/5K2/8/5P2/P7/8 b - - 0 54')

# %%
push('b7a8')
# Out:
# Board('k7/2b2P2/6P1/5K2/8/5P2/P7/8 w - - 0 55')

# %%
make_move()
# Out:
# Board('k7/2b2PP1/8/5K2/8/5P2/P7/8 b - - 0 55')

# %%
push('c7d6')
# Out:
# Board('k7/5PP1/3b4/5K2/8/5P2/P7/8 w - - 1 56')

# %%
make_move()
# Out:
# Board('k7/5PP1/3b2K1/8/8/5P2/P7/8 b - - 2 56')

# %%
push('a8b7')
# Out:
# Board('8/1k3PP1/3b2K1/8/8/5P2/P7/8 w - - 3 57')

# %%
make_move()
# Out:
# Board('5P2/1k4P1/3b2K1/8/8/5P2/P7/8 b - - 0 57')

# %%
b.pop()
# Out:
# Move.from_uci('f7f8')

# %%
b
# Out:
# Board('8/1k3PP1/3b2K1/8/8/5P2/P7/8 w - - 3 57')

# %%
b.push(chess.Move.from_uci('f7f8q'))

# %%
b
# Out:
# Board('5Q2/1k4P1/3b2K1/8/8/5P2/P7/8 b - - 0 57')

# %%
push('b7c6')
# Out:
# Board('5Q2/6P1/2kb2K1/8/8/5P2/P7/8 w - - 1 58')

# %%
make_move()
# Out:
# Board('5Q2/6P1/2kb2K1/8/P7/5P2/8/8 b - - 0 58')

# %%
push('c6c5')
# Out:
# Board('5Q2/6P1/3b2K1/2k5/P7/5P2/8/8 w - - 1 59')

# %%
make_move()
# Out:
# Board('5QP1/8/3b2K1/2k5/P7/5P2/8/8 b - - 0 59')

# %%
b.pop()
# Out:
# Move.from_uci('g7g8')

# %%
b.push(chess.Move.from_uci('g7g8q'))

# %%
b
# Out:
# Board('5QQ1/8/3b2K1/2k5/P7/5P2/8/8 b - - 0 59')

# %%
push('c5b4')
# Out:
# Board('5QQ1/8/3b2K1/8/Pk6/5P2/8/8 w - - 1 60')

# %%
make_move()
# Out:
# Board('6Q1/8/3Q2K1/8/Pk6/5P2/8/8 b - - 0 60')

# %%
push('b4a4')
# Out:
# Board('6Q1/8/3Q2K1/8/k7/5P2/8/8 w - - 0 61')

# %%
make_move()
# Out:
# Board('6Q1/8/6K1/8/k2Q4/5P2/8/8 b - - 1 61')

# %%
push('a4b5')
# Out:
# Board('6Q1/8/6K1/1k6/3Q4/5P2/8/8 w - - 2 62')

# %%
make_move()
# Out:
# Board('6Q1/8/6K1/1k1Q4/8/5P2/8/8 b - - 3 62')

# %%
push('b5b4')
# Out:
# Board('6Q1/8/6K1/3Q4/1k6/5P2/8/8 w - - 4 63')

# %%
make_move()
# Out:
# Board('6Q1/8/6K1/8/1k1Q4/5P2/8/8 b - - 5 63')

# %%
push('b4a3')
# Out:
# Board('6Q1/8/6K1/8/3Q4/k4P2/8/8 w - - 6 64')

# %%
make_move()
# Out:
# Board('6Q1/8/6K1/8/3Q1P2/k7/8/8 b - - 0 64')

# %%
b.is_game_over()
# Out:
# True
